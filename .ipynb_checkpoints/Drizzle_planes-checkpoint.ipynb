# %% [markdown]
# ### Aviation Data

# %% [markdown]
# Over the past few years , we as Drizzle plane company have been having a drop in profits and raise in losses especially due to the number of old planes within the company.

# %% [markdown]
# After careful consideration , I as the data analyst of the firm had to come up with a proposal especially affter careful consideration through the National Transportation Safety Board ,I was granted access to data containing the number of accidents new and technologized planes have undergone and in which parts of the country are affected by this.

# %% [markdown]
# Some of the reasons why this is good informattion is because most of the decision comes from careful analysation of the data provided. We may come up with different plane types to consider for purchase especially if we are planning to change the rate at which the company impacts the society.

# %% [markdown]
# Inorder for us to come up with a clear cosideration and proposal for the stakeholders ,we have to go through and visualize through the data provided. For this to start, we have to first load the data from the main source and clean it thourougly then finally ccome up with different visualizations that will aid in the passing of the proposal.

# %%
#Step 1 is loading the packages that will help in coming up with the proposal
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Now that we have loaded the packages to process the data given to us , we can now open the files and check the dataset structure for both

# %%
#We have loaded the first document (AviationData) as a dataset called df_aviationdata.
df_aviationdata = pd.read_csv('AviationData.csv',encoding = 'latin1',low_memory=False)
df_aviationdata.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Total.Fatal.Injuries  \
# count  88889.000000  88889.000000    88889.000000          88889.000000
# mean   44444.000000  44444.000000    44444.000000              0.647855
# std    25660.188376  25660.188376    25660.188376              5.122070
# min        0.000000      0.000000        0.000000              0.000000
# 25%    22222.000000  22222.000000    22222.000000              0.000000
# 50%    44444.000000  44444.000000    44444.000000              0.000000
# 75%    66666.000000  66666.000000    66666.000000              0.647855
# max    88888.000000  88888.000000    88888.000000            349.000000
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured
# count            88889.000000          88889.000000     88889.000000
# mean                 0.279881              0.309127         5.037755
# std                  1.431309              2.083715        26.990914
# min                  0.000000              0.000000         0.000000
# 25%                  0.000000              0.000000         0.000000
# 50%                  0.000000              0.000000         1.000000
# 75%                  0.279881              0.000000         2.000000
# max                161.000000            380.000000       699.000000

# %% [markdown]
#  Now that the dataset has been loaded into our working area , we can now check the validity and shape of the dataset to confirm its eligibility within the work environment

# %% [markdown]
# We can check the order at which the dataset is loaded using head() attribute and the shape() attribute to also confirm validity

# %%
# Now that we have both data structures well confirmed and verrified for continuation, we will proceed to data cleaning.
df_aviationdata.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 Investigation.Type Accident.Number  Event.Date  \
# 0           0             0           Accident      SEA87LA080  1948-10-24
# 1           1             1           Accident      LAX94LA336  1962-07-19
# 2           2             2           Accident      NYC07LA005  1974-08-30
# 3           3             3           Accident      LAX96LA321  1977-06-19
# 4           4             4           Accident      CHI79FA064  1979-08-02
#
#          Country Aircraft.Category      Make     Model Amateur.Built  \
# 0  United States           Unknown   Stinson     108-3            No
# 1  United States           Unknown     Piper  PA24-180            No
# 2  United States           Unknown    Cessna      172M            No
# 3  United States           Unknown  Rockwell       112            No
# 4  United States           Unknown    Cessna       501            No
#
#    Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 0                   2.0                0.000000                   0.0
# 1                   4.0                0.000000                   0.0
# 2                   3.0                0.279881                   0.0
# 3                   2.0                0.000000                   0.0
# 4                   1.0                2.000000                   0.0
#
#    Total.Uninjured Weather.Condition         US_State
# 0              0.0               UNK  MOOSE CREEK, ID
# 1              0.0               UNK   BRIDGEPORT, CA
# 2              1.0               IMC    Saltville, VA
# 3              0.0               IMC       EUREKA, CA
# 4              0.0               VMC       Canton, OH

# %% [markdown]
# ## DATA UNDERSTANDING

# %% [markdown]
# To clearly understand what this data entails , we have to go through it step by step.First step is to check the type of data present in the dataset .

# %%
#checking the original shape of the aviation data dataset
df_aviationdata.shape
# Out:
# (88889, 17)

# %% [markdown]
# We also have to check the information provided in both datasets . We can do this in two different lines to understand the two.

# %%
df_aviationdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              88889 non-null  int64
#  1   Unnamed: 0.1            88889 non-null  int64
#  2   Unnamed: 0.1.1          88889 non-null  int64
#  3   Investigation.Type      88889 non-null  object
#  4   Accident.Number         88889 non-null  object
#  5   Event.Date              88889 non-null  object
#  6   Country                 88889 non-null  object
#  7   Aircraft.Category       88889 non-null  object
#  8   Make                    88826 non-null  object
#  9   Model                   88797 non-null  object
#  10  Amateur.Built           88787 non-null  object
#  11  Total.Fatal.Injuries    88889 non-null  float64
#  12  Total.Serious.Injuries  88889 non-null  float64
#  13  Total.Minor.Injuries    88889 non-null  float64
#  14  Total.Uninjured         88889 non-null  float64
#  15  Weather.Condition       88889 non-null  object
#  16  US_State                88889 non-null  object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 11.5+ MB

# %% [markdown]
# Now that we have all information regarding the datasets , we can now move to copying the datasets and choosing specific columns to aid in our data presentation

# %% [markdown]
# ## Data manipulation

# %%
#check columns present in df_aviation data and choose specific columns for manipulation
df_aviationdata.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Investigation.Type',
#        'Accident.Number', 'Event.Date', 'Country', 'Aircraft.Category', 'Make',
#        'Model', 'Amateur.Built', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'US_State'],
#       dtype='object')

# %%
#copying the code to a different datset so as to avoid disturbing the original dataset
df2 = df_aviationdata.copy()

# %%
df2.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 Investigation.Type  \
# 0           0             0               0           Accident
# 1           1             1               1           Accident
# 2           2             2               2           Accident
# 3           3             3               3           Accident
# 4           4             4               4           Accident
#
#   Accident.Number  Event.Date        Country Aircraft.Category      Make  \
# 0      SEA87LA080  1948-10-24  United States           Unknown   Stinson
# 1      LAX94LA336  1962-07-19  United States           Unknown     Piper
# 2      NYC07LA005  1974-08-30  United States           Unknown    Cessna
# 3      LAX96LA321  1977-06-19  United States           Unknown  Rockwell
# 4      CHI79FA064  1979-08-02  United States           Unknown    Cessna
#
#       Model Amateur.Built  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 0     108-3            No                   2.0                0.000000
# 1  PA24-180            No                   4.0                0.000000
# 2      172M            No                   3.0                0.279881
# 3       112            No                   2.0                0.000000
# 4       501            No                   1.0                2.000000
#
#    Total.Minor.Injuries  Total.Uninjured Weather.Condition         US_State
# 0                   0.0              0.0               UNK  MOOSE CREEK, ID
# 1                   0.0              0.0               UNK   BRIDGEPORT, CA
# 2                   0.0              1.0               IMC    Saltville, VA
# 3                   0.0              0.0               IMC       EUREKA, CA
# 4                   0.0              0.0               VMC       Canton, OH

# %%
#to clearly choose columns, we have already dropped the unwanted columns now we check for presence of any null values.
df2.isnull().sum()
# Out:
# Unnamed: 0                  0
# Unnamed: 0.1                0
# Unnamed: 0.1.1              0
# Investigation.Type          0
# Accident.Number             0
# Event.Date                  0
# Country                     0
# Aircraft.Category           0
# Make                       63
# Model                      92
# Amateur.Built             102
# Total.Fatal.Injuries        0
# Total.Serious.Injuries      0
# Total.Minor.Injuries        0
# Total.Uninjured             0
# Weather.Condition           0
# US_State                    0
# dtype: int64

# %%
#presence of null values in column make,model and even Amateur.Built
df2
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 Investigation.Type  \
# 0               0             0               0           Accident
# 1               1             1               1           Accident
# 2               2             2               2           Accident
# 3               3             3               3           Accident
# 4               4             4               4           Accident
# ...           ...           ...             ...                ...
# 88884       88884         88884           88884           Accident
# 88885       88885         88885           88885           Accident
# 88886       88886         88886           88886           Accident
# 88887       88887         88887           88887           Accident
# 88888       88888         88888           88888           Accident
#
#       Accident.Number  Event.Date        Country Aircraft.Category  \
# 0          SEA87LA080  1948-10-24  United States           Unknown
# 1          LAX94LA336  1962-07-19  United States           Unknown
# 2          NYC07LA005  1974-08-30  United States           Unknown
# 3          LAX96LA321  1977-06-19  United States           Unknown
# 4          CHI79FA064  1979-08-02  United States           Unknown
# ...               ...         ...            ...               ...
# 88884      ERA23LA093  2022-12-26  United States           Unknown
# 88885      ERA23LA095  2022-12-26  United States           Unknown
# 88886      WPR23LA075  2022-12-26  United States          Airplane
# 88887      WPR23LA076  2022-12-26  United States           Unknown
# 88888      ERA23LA097  2022-12-29  United States           Unknown
#
#                              Make      Model Amateur.Built  \
# 0                         Stinson      108-3            No
# 1                           Piper   PA24-180            No
# 2                          Cessna       172M            No
# 3                        Rockwell        112            No
# 4                          Cessna        501            No
# ...                           ...        ...           ...
# 88884                       PIPER  PA-28-151            No
# 88885                    BELLANCA       7ECA            No
# 88886  AMERICAN CHAMPION AIRCRAFT      8GCBC            No
# 88887                      CESSNA       210N            No
# 88888                       PIPER  PA-24-260            No
#
#        Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 0                       2.0                0.000000                   0.0
# 1                       4.0                0.000000                   0.0
# 2                       3.0                0.279881                   0.0
# 3                       2.0                0.000000                   0.0
# 4                       1.0                2.000000                   0.0
# ...                     ...                     ...                   ...
# 88884                   0.0                1.000000                   0.0
# 88885                   0.0                0.000000                   0.0
# 88886                   0.0                0.000000                   0.0
# 88887                   0.0                0.000000                   0.0
# 88888                   0.0                1.000000                   0.0
#
#        Total.Uninjured Weather.Condition         US_State
# 0                  0.0               UNK  MOOSE CREEK, ID
# 1                  0.0               UNK   BRIDGEPORT, CA
# 2                  1.0               IMC    Saltville, VA
# 3                  0.0               IMC       EUREKA, CA
# 4                  0.0               VMC       Canton, OH
# ...                ...               ...              ...
# 88884              0.0           Unknown    Annapolis, MD
# 88885              0.0           Unknown      Hampton, NH
# 88886              1.0               VMC       Payson, AZ
# 88887              0.0           Unknown       Morgan, UT
# 88888              1.0           Unknown       Athens, GA
#
# [88889 rows x 17 columns]

# %%
#dropping the columns(due to them being already dropped an error keeps coming up)
df2.drop('Amateur.Built',axis=1,inplace =True)
df2
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 Investigation.Type  \
# 0               0             0               0           Accident
# 1               1             1               1           Accident
# 2               2             2               2           Accident
# 3               3             3               3           Accident
# 4               4             4               4           Accident
# ...           ...           ...             ...                ...
# 88884       88884         88884           88884           Accident
# 88885       88885         88885           88885           Accident
# 88886       88886         88886           88886           Accident
# 88887       88887         88887           88887           Accident
# 88888       88888         88888           88888           Accident
#
#       Accident.Number  Event.Date        Country Aircraft.Category  \
# 0          SEA87LA080  1948-10-24  United States           Unknown
# 1          LAX94LA336  1962-07-19  United States           Unknown
# 2          NYC07LA005  1974-08-30  United States           Unknown
# 3          LAX96LA321  1977-06-19  United States           Unknown
# 4          CHI79FA064  1979-08-02  United States           Unknown
# ...               ...         ...            ...               ...
# 88884      ERA23LA093  2022-12-26  United States           Unknown
# 88885      ERA23LA095  2022-12-26  United States           Unknown
# 88886      WPR23LA075  2022-12-26  United States          Airplane
# 88887      WPR23LA076  2022-12-26  United States           Unknown
# 88888      ERA23LA097  2022-12-29  United States           Unknown
#
#                              Make      Model  Total.Fatal.Injuries  \
# 0                         Stinson      108-3                   2.0
# 1                           Piper   PA24-180                   4.0
# 2                          Cessna       172M                   3.0
# 3                        Rockwell        112                   2.0
# 4                          Cessna        501                   1.0
# ...                           ...        ...                   ...
# 88884                       PIPER  PA-28-151                   0.0
# 88885                    BELLANCA       7ECA                   0.0
# 88886  AMERICAN CHAMPION AIRCRAFT      8GCBC                   0.0
# 88887                      CESSNA       210N                   0.0
# 88888                       PIPER  PA-24-260                   0.0
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# 0                    0.000000                   0.0              0.0
# 1                    0.000000                   0.0              0.0
# 2                    0.279881                   0.0              1.0
# 3                    0.000000                   0.0              0.0
# 4                    2.000000                   0.0              0.0
# ...                       ...                   ...              ...
# 88884                1.000000                   0.0              0.0
# 88885                0.000000                   0.0              0.0
# 88886                0.000000                   0.0              1.0
# 88887                0.000000                   0.0              0.0
# 88888                1.000000                   0.0              1.0
#
#       Weather.Condition         US_State
# 0                   UNK  MOOSE CREEK, ID
# 1                   UNK   BRIDGEPORT, CA
# 2                   IMC    Saltville, VA
# 3                   IMC       EUREKA, CA
# 4                   VMC       Canton, OH
# ...                 ...              ...
# 88884           Unknown    Annapolis, MD
# 88885           Unknown      Hampton, NH
# 88886               VMC       Payson, AZ
# 88887           Unknown       Morgan, UT
# 88888           Unknown       Athens, GA
#
# [88889 rows x 16 columns]

# %% [markdown]
# ## Dropping of null values

# %% [markdown]
# After dropping the unwanted columns , we can now dwell deep in the data by going through all columns to ascertain that no null values are present

# %%
#now we can deal with the categorical null values using Aircraft.Category as the first column
df2['Aircraft.Category'].unique()
# Out:
# array(['Unknown', 'Airplane', 'Helicopter', 'Glider', 'Balloon',
#        'Gyrocraft', 'Ultralight', 'Blimp', 'Powered-Lift', 'Weight-Shift',
#        'Powered Parachute', 'Rocket', 'WSFT', 'UNK', 'ULTR'], dtype=object)

# %%
#after running the code below,we came to the understanding that there is no presence of any null values, so we can move to the next column
df2['Aircraft.Category'].isnull().sum()
# Out:
# 0

# %%
df2['Aircraft.Category'].fillna('Unknown',inplace=True)
df2
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 Investigation.Type  \
# 0               0             0               0           Accident
# 1               1             1               1           Accident
# 2               2             2               2           Accident
# 3               3             3               3           Accident
# 4               4             4               4           Accident
# ...           ...           ...             ...                ...
# 88884       88884         88884           88884           Accident
# 88885       88885         88885           88885           Accident
# 88886       88886         88886           88886           Accident
# 88887       88887         88887           88887           Accident
# 88888       88888         88888           88888           Accident
#
#       Accident.Number  Event.Date        Country Aircraft.Category  \
# 0          SEA87LA080  1948-10-24  United States           Unknown
# 1          LAX94LA336  1962-07-19  United States           Unknown
# 2          NYC07LA005  1974-08-30  United States           Unknown
# 3          LAX96LA321  1977-06-19  United States           Unknown
# 4          CHI79FA064  1979-08-02  United States           Unknown
# ...               ...         ...            ...               ...
# 88884      ERA23LA093  2022-12-26  United States           Unknown
# 88885      ERA23LA095  2022-12-26  United States           Unknown
# 88886      WPR23LA075  2022-12-26  United States          Airplane
# 88887      WPR23LA076  2022-12-26  United States           Unknown
# 88888      ERA23LA097  2022-12-29  United States           Unknown
#
#                              Make      Model  Total.Fatal.Injuries  \
# 0                         Stinson      108-3                   2.0
# 1                           Piper   PA24-180                   4.0
# 2                          Cessna       172M                   3.0
# 3                        Rockwell        112                   2.0
# 4                          Cessna        501                   1.0
# ...                           ...        ...                   ...
# 88884                       PIPER  PA-28-151                   0.0
# 88885                    BELLANCA       7ECA                   0.0
# 88886  AMERICAN CHAMPION AIRCRAFT      8GCBC                   0.0
# 88887                      CESSNA       210N                   0.0
# 88888                       PIPER  PA-24-260                   0.0
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# 0                    0.000000                   0.0              0.0
# 1                    0.000000                   0.0              0.0
# 2                    0.279881                   0.0              1.0
# 3                    0.000000                   0.0              0.0
# 4                    2.000000                   0.0              0.0
# ...                       ...                   ...              ...
# 88884                1.000000                   0.0              0.0
# 88885                0.000000                   0.0              0.0
# 88886                0.000000                   0.0              1.0
# 88887                0.000000                   0.0              0.0
# 88888                1.000000                   0.0              1.0
#
#       Weather.Condition         US_State
# 0                   UNK  MOOSE CREEK, ID
# 1                   UNK   BRIDGEPORT, CA
# 2                   IMC    Saltville, VA
# 3                   IMC       EUREKA, CA
# 4                   VMC       Canton, OH
# ...                 ...              ...
# 88884           Unknown    Annapolis, MD
# 88885           Unknown      Hampton, NH
# 88886               VMC       Payson, AZ
# 88887           Unknown       Morgan, UT
# 88888           Unknown       Athens, GA
#
# [88889 rows x 16 columns]

# %%
#here we can check the null values for column make.
df2['Make'].unique()
# Out:
# array(['Stinson', 'Piper', 'Cessna', ..., 'JAMES R DERNOVSEK',
#        'ORLICAN S R O', 'ROYSE RALPH L'], dtype=object)

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0                 0
# Unnamed: 0.1               0
# Unnamed: 0.1.1             0
# Investigation.Type         0
# Accident.Number            0
# Event.Date                 0
# Country                    0
# Aircraft.Category          0
# Make                      63
# Model                     92
# Total.Fatal.Injuries       0
# Total.Serious.Injuries     0
# Total.Minor.Injuries       0
# Total.Uninjured            0
# Weather.Condition          0
# US_State                   0
# dtype: int64

# %% [markdown]
# After proper understanding, we have seen that the most affected columns have been dropped and the remaining we would just need to impute them.

# %% [markdown]
# ## Imputing of null columns

# %% [markdown]
# Imputing would mean to properly change values present in a data column.This could be done through using of the mean mode value and even median value for numericals and for strings we would be required to fill in the values with a placeholder value for the data to work properly.

# %%
# We use this on column 'Total.Fatal.Injuries' and filling the values with the mode value of the column(most repeated).
df2['Total.Fatal.Injuries'].fillna(df2['Total.Fatal.Injuries'].mode(),inplace=True)

# %%
#checking the null values after using the attribute fillna
df2['Total.Fatal.Injuries'].isnull().sum()
# Out:
# 0

# %%
# We ccan use the mean value on the column 'Total.Serious.Injuries'
df2['Total.Serious.Injuries'].fillna(df2['Total.Serious.Injuries'].mean(),inplace=True)

# %%
#check for null values within the column
df2['Total.Serious.Injuries'].isnull().sum()
# Out:
# 0

# %%
# We can use the median value to fill in null values in the column but because it contains numerical values we are required to use the mean value of the column.
df2['Total.Minor.Injuries'].fillna(df2['Total.Minor.Injuries'].mean(),inplace=True)

# %%
#check null values
df2['Total.Minor.Injuries'].isnull().sum()
# Out:
# 0

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0                 0
# Unnamed: 0.1               0
# Unnamed: 0.1.1             0
# Investigation.Type         0
# Accident.Number            0
# Event.Date                 0
# Country                    0
# Aircraft.Category          0
# Make                      63
# Model                     92
# Total.Fatal.Injuries       0
# Total.Serious.Injuries     0
# Total.Minor.Injuries       0
# Total.Uninjured            0
# Weather.Condition          0
# US_State                   0
# dtype: int64

# %% [markdown]
# After completing the imputations we still can see that some values are null and so we have to either decide if it will help us with our final product or if its better to work without the two columns. We can decide to drop one then remain with the other one (drop model tho remain with make)

# %%
df2.drop('Model',axis=1,inplace = True)
df2
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 Investigation.Type  \
# 0               0             0               0           Accident
# 1               1             1               1           Accident
# 2               2             2               2           Accident
# 3               3             3               3           Accident
# 4               4             4               4           Accident
# ...           ...           ...             ...                ...
# 88884       88884         88884           88884           Accident
# 88885       88885         88885           88885           Accident
# 88886       88886         88886           88886           Accident
# 88887       88887         88887           88887           Accident
# 88888       88888         88888           88888           Accident
#
#       Accident.Number  Event.Date        Country Aircraft.Category  \
# 0          SEA87LA080  1948-10-24  United States           Unknown
# 1          LAX94LA336  1962-07-19  United States           Unknown
# 2          NYC07LA005  1974-08-30  United States           Unknown
# 3          LAX96LA321  1977-06-19  United States           Unknown
# 4          CHI79FA064  1979-08-02  United States           Unknown
# ...               ...         ...            ...               ...
# 88884      ERA23LA093  2022-12-26  United States           Unknown
# 88885      ERA23LA095  2022-12-26  United States           Unknown
# 88886      WPR23LA075  2022-12-26  United States          Airplane
# 88887      WPR23LA076  2022-12-26  United States           Unknown
# 88888      ERA23LA097  2022-12-29  United States           Unknown
#
#                              Make  Total.Fatal.Injuries  \
# 0                         Stinson                   2.0
# 1                           Piper                   4.0
# 2                          Cessna                   3.0
# 3                        Rockwell                   2.0
# 4                          Cessna                   1.0
# ...                           ...                   ...
# 88884                       PIPER                   0.0
# 88885                    BELLANCA                   0.0
# 88886  AMERICAN CHAMPION AIRCRAFT                   0.0
# 88887                      CESSNA                   0.0
# 88888                       PIPER                   0.0
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# 0                    0.000000                   0.0              0.0
# 1                    0.000000                   0.0              0.0
# 2                    0.279881                   0.0              1.0
# 3                    0.000000                   0.0              0.0
# 4                    2.000000                   0.0              0.0
# ...                       ...                   ...              ...
# 88884                1.000000                   0.0              0.0
# 88885                0.000000                   0.0              0.0
# 88886                0.000000                   0.0              1.0
# 88887                0.000000                   0.0              0.0
# 88888                1.000000                   0.0              1.0
#
#       Weather.Condition         US_State
# 0                   UNK  MOOSE CREEK, ID
# 1                   UNK   BRIDGEPORT, CA
# 2                   IMC    Saltville, VA
# 3                   IMC       EUREKA, CA
# 4                   VMC       Canton, OH
# ...                 ...              ...
# 88884           Unknown    Annapolis, MD
# 88885           Unknown      Hampton, NH
# 88886               VMC       Payson, AZ
# 88887           Unknown       Morgan, UT
# 88888           Unknown       Athens, GA
#
# [88889 rows x 15 columns]

# %%
#df2['Total.Uninjured'].fillna(df2['Total.Uninjured'].median(),inplace=True)

# %%
#df2['Weather.Condition'].fillna('Unknown',inplace=True)

# %%
# we can now fill the null values present in column 'Make' to obtain clear and complete data

# %%
df2['Make'].fillna('Unknown',axis=0,inplace=True)

# %%
df2
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 Investigation.Type  \
# 0               0             0               0           Accident
# 1               1             1               1           Accident
# 2               2             2               2           Accident
# 3               3             3               3           Accident
# 4               4             4               4           Accident
# ...           ...           ...             ...                ...
# 88884       88884         88884           88884           Accident
# 88885       88885         88885           88885           Accident
# 88886       88886         88886           88886           Accident
# 88887       88887         88887           88887           Accident
# 88888       88888         88888           88888           Accident
#
#       Accident.Number  Event.Date        Country Aircraft.Category  \
# 0          SEA87LA080  1948-10-24  United States           Unknown
# 1          LAX94LA336  1962-07-19  United States           Unknown
# 2          NYC07LA005  1974-08-30  United States           Unknown
# 3          LAX96LA321  1977-06-19  United States           Unknown
# 4          CHI79FA064  1979-08-02  United States           Unknown
# ...               ...         ...            ...               ...
# 88884      ERA23LA093  2022-12-26  United States           Unknown
# 88885      ERA23LA095  2022-12-26  United States           Unknown
# 88886      WPR23LA075  2022-12-26  United States          Airplane
# 88887      WPR23LA076  2022-12-26  United States           Unknown
# 88888      ERA23LA097  2022-12-29  United States           Unknown
#
#                              Make  Total.Fatal.Injuries  \
# 0                         Stinson                   2.0
# 1                           Piper                   4.0
# 2                          Cessna                   3.0
# 3                        Rockwell                   2.0
# 4                          Cessna                   1.0
# ...                           ...                   ...
# 88884                       PIPER                   0.0
# 88885                    BELLANCA                   0.0
# 88886  AMERICAN CHAMPION AIRCRAFT                   0.0
# 88887                      CESSNA                   0.0
# 88888                       PIPER                   0.0
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# 0                    0.000000                   0.0              0.0
# 1                    0.000000                   0.0              0.0
# 2                    0.279881                   0.0              1.0
# 3                    0.000000                   0.0              0.0
# 4                    2.000000                   0.0              0.0
# ...                       ...                   ...              ...
# 88884                1.000000                   0.0              0.0
# 88885                0.000000                   0.0              0.0
# 88886                0.000000                   0.0              1.0
# 88887                0.000000                   0.0              0.0
# 88888                1.000000                   0.0              1.0
#
#       Weather.Condition         US_State
# 0                   UNK  MOOSE CREEK, ID
# 1                   UNK   BRIDGEPORT, CA
# 2                   IMC    Saltville, VA
# 3                   IMC       EUREKA, CA
# 4                   VMC       Canton, OH
# ...                 ...              ...
# 88884           Unknown    Annapolis, MD
# 88885           Unknown      Hampton, NH
# 88886               VMC       Payson, AZ
# 88887           Unknown       Morgan, UT
# 88888           Unknown       Athens, GA
#
# [88889 rows x 15 columns]

# %%
#check for any new null values
df2.isnull().sum()
# Out:
# Unnamed: 0                0
# Unnamed: 0.1              0
# Unnamed: 0.1.1            0
# Investigation.Type        0
# Accident.Number           0
# Event.Date                0
# Country                   0
# Aircraft.Category         0
# Make                      0
# Total.Fatal.Injuries      0
# Total.Serious.Injuries    0
# Total.Minor.Injuries      0
# Total.Uninjured           0
# Weather.Condition         0
# US_State                  0
# dtype: int64

# %% [markdown]
# Now that we have cleared most of the null values in the dataset we can finally move to saving the new dataset as a new and cleaned dataset

# %%
#dropping the new unrequired fields for better data understanding 
df2.drop(['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1'],axis = 1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-e9504607bc4b> in <module>
#       1 #dropping the new unrequired fields for better data understanding
# ----> 2 df2.drop(['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1'],axis = 1,inplace=True)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0' 'Unnamed: 0.1' 'Unnamed: 0.1.1'] not found in axis"

# %%
df2.columns
# Out:
# Index(['Investigation.Type', 'Accident.Number', 'Event.Date', 'Country',
#        'Aircraft.Category', 'Make', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'US_State'],
#       dtype='object')

# %%
df2.shape
# Out:
# (88889, 12)

# %% [markdown]
# After clear understanding of the data , we can go ahead and save the dataset as the new dataset to work with

# %%
df2.to_csv('Aviation_Data.csv', index=True)

# %% [markdown]
# ## Data visualization

# %% [markdown]
# For this , we would need to go through the relations present between values in the dataset

# %%
corr_df2 = df2.corr()

# %%
corr_df2 =corr_df2.fillna(0)

# %%
plt.figure(figsize=(8,8))
sns.heatmap(corr_df2,annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
